# %%
# !git init -b main
# Out:
# Initialized empty Git repository in /home/meco/Nextcloud2/Projects/RUSITEC/Rusitec_2020/Git/.git/

# %%
# !git remote add origin git@github.com:timyerg/Rusitec_2020.git
# !git remote -v
# Out:
# origin	git@github.com:timyerg/Rusitec_2020.git (fetch)
# origin	git@github.com:timyerg/Rusitec_2020.git (push)

# %%
# !git add .

# %%
# !git commit -m 'First commit'
# Out:
# [main (root-commit) 6fb4397] First commit
#  467 files changed, 246383 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Git-checkpoint.ipynb
#  create mode 100644 Amplicons/Amplicons_2020.ipynb
#  create mode 100644 Amplicons/Classifier-GTDB.ipynb
#  create mode 100644 Amplicons/Data/Archaea-rep-seqs.qza
#  create mode 100644 Amplicons/Data/Archaea-rooted_tree.qza
#  create mode 100644 Amplicons/Data/Archaea-taxonomy.qza
#  create mode 100644 Amplicons/Data/Archaea-taxonomy.qzv
#  create mode 100644 Amplicons/Data/Archaea-taxonomy/taxonomy.tsv
#  create mode 100644 Amplicons/Data/Bacteria-rep-seqs.qza
#  create mode 100644 Amplicons/Data/Bacteria-rooted_tree.qza
#  create mode 100644 Amplicons/Data/Bacteria-taxonomy.qza
#  create mode 100644 Amplicons/Data/Bacteria-taxonomy.qzv
#  create mode 100644 Amplicons/Data/Bacteria-taxonomy/taxonomy.tsv
#  create mode 100644 Amplicons/Data/Dada2/r1_L1_rep-seqs.qza
#  create mode 100644 Amplicons/Data/Dada2/r1_L1_rep-seqs.qzv
#  create mode 100644 Amplicons/Data/Dada2/r1_L1_stats.qza
#  create mode 100644 Amplicons/Data/Dada2/r1_L1_stats.qzv
#  create mode 100644 Amplicons/Data/Dada2/r1_L1_table.qza
#  create mode 100644 Amplicons/Data/Dada2/r1_L1_table.qzv
#  create mode 100644 Amplicons/Data/Dada2/r1_L2_rep-seqs.qza
#  create mode 100644 Amplicons/Data/Dada2/r1_L2_rep-seqs.qzv
#  create mode 100644 Amplicons/Data/Dada2/r1_L2_stats.qza
#  create mode 100644 Amplicons/Data/Dada2/r1_L2_stats.qzv
#  create mode 100644 Amplicons/Data/Dada2/r1_L2_table.qza
#  create mode 100644 Amplicons/Data/Dada2/r1_L2_table.qzv
#  create mode 100644 Amplicons/Data/Dada2/r2_L1_rep-seqs.qza
#  create mode 100644 Amplicons/Data/Dada2/r2_L1_rep-seqs.qzv
#  create mode 100644 Amplicons/Data/Dada2/r2_L1_stats.qza
#  create mode 100644 Amplicons/Data/Dada2/r2_L1_stats.qzv
#  create mode 100644 Amplicons/Data/Dada2/r2_L1_table.qza
#  create mode 100644 Amplicons/Data/Dada2/r2_L1_table.qzv
#  create mode 100644 Amplicons/Data/Dada2/r3_L2_rep-seqs.qza
#  create mode 100644 Amplicons/Data/Dada2/r3_L2_rep-seqs.qzv
#  create mode 100644 Amplicons/Data/Dada2/r3_L2_stats.qza
#  create mode 100644 Amplicons/Data/Dada2/r3_L2_stats.qzv
#  create mode 100644 Amplicons/Data/Dada2/r3_L2_table.qza
#  create mode 100644 Amplicons/Data/Dada2/r3_L2_table.qzv
#  create mode 100644 Amplicons/Data/Tables/Archaea-table.qza
#  create mode 100644 Amplicons/Data/Tables/Archaea-table.qzv
#  create mode 100644 Amplicons/Data/Tables/Bacteria-table.qza
#  create mode 100644 Amplicons/Data/Tables/Bacteria-table.qzv
#  create mode 100755 Amplicons/Descriptions/Barcodes.tsv
#  create mode 100755 Amplicons/Descriptions/Data HGT 2020.xlsx
#  create mode 100755 Amplicons/Descriptions/Data Rusitec 2020.csv
#  create mode 100755 Amplicons/Descriptions/HGT.tsv
#  create mode 100755 Amplicons/Descriptions/Metadata and demultiplexing.ipynb
#  create mode 100755 Amplicons/Descriptions/Microbiota overall overview.docx
#  create mode 100755 Amplicons/Descriptions/NutrientRusitec 2020.csv
#  create mode 100755 Amplicons/Descriptions/Replacement.tsv
#  create mode 100755 Amplicons/Descriptions/Rusitec2020_master plan.docx
#  create mode 100755 Amplicons/Descriptions/Sample_descitions.tsv
#  create mode 100755 Amplicons/Descriptions/Samplinglist Microbiota_Rusitec 2020.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_AP_r2_i11_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_AP_r2_i6 9 11_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_AP_r2_i6_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_AP_r2_i9_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_MC_r1_i10 12_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_MC_r1_i10_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_MC_r1_i12_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i1 2 3 5 8 10 12_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i10_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i12_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i1_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i2_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i3_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i5_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_PP_r1_i8_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_RS_r3_i12_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_RS_r3_i12_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_SH_r2_i11_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_SH_r2_i11_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r2_i1 3 4 5 6_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r2_i1_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r2_i3_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r2_i4_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r2_i5_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r2_i6_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i11_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i12_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i2 6 7 8 9 11 12_M.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i2_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i6_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i7_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i8_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Mothur/PP2_TB_r3_i9_M.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_AP_r2_i11_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_AP_r2_i6 9 11_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_AP_r2_i6_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_AP_r2_i9_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_MC_r1_i10 12_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_MC_r1_i10_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_MC_r1_i12_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i1 2 3 5 8 10 12_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i10_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i12_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i1_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i2_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i3_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i5_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_PP_r1_i8_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_RS_r3_i12_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_RS_r3_i12_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_SH_r2_i11_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_SH_r2_i11_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r2_i1 3 4 5 6_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r2_i1_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r2_i3_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r2_i4_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r2_i5_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r2_i6_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i11_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i12_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i2 6 7 8 9 11 12_Q.xlsx
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i2_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i6_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i7_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i8_Q.txt
#  create mode 100755 Amplicons/Descriptions/Sorted barcodes_ProtiPig2/ProtiPig2_Qiime/PP2_TB_r3_i9_Q.txt
#  create mode 100644 Amplicons/Fermentation.ipynb
#  create mode 100644 Amplicons/Figures/Alpha_diversity/faith_pd-ANOVA-Trt.png
#  create mode 100644 Amplicons/Figures/Alpha_diversity/faith_pd-ANOVA_residulas-Trt.png
#  create mode 100644 Amplicons/Figures/Alpha_diversity/faith_pd-Trt.png
#  create mode 100644 Amplicons/Figures/Alpha_diversity/shannon-ANOVA-Trt.png
#  create mode 100644 Amplicons/Figures/Alpha_diversity/shannon-ANOVA_residulas-Trt.png
#  create mode 100644 Amplicons/Figures/Alpha_diversity/shannon-Trt.png
#  create mode 100644 Amplicons/Figures/AncomBC/AncomBC.png
#  create mode 100644 Amplicons/Figures/Beta/Boxplot_Amplicons_Trts_bray_curtis_.png
#  create mode 100644 Amplicons/Figures/Beta/PCOA_Amplicons_bray_curtis.png
#  create mode 100644 Amplicons/Figures/Beta/PCOA_Distances_Amplicons_bray_curtis.png
#  create mode 100644 Amplicons/Figures/TG_CH4/TG-CH4c_HGT-RSTC.png
#  create mode 100644 Amplicons/Figures/Taxabarplots/AB_ratios.png
#  create mode 100644 Amplicons/Figures/Taxabarplots/Taxabarplot_sType.png
#  create mode 100644 Amplicons/Results/Adonis/Archaea_Trt_adonis.tsv
#  create mode 100644 Amplicons/Results/Adonis/Archaea_sType_adonis.tsv
#  create mode 100644 Amplicons/Results/Adonis/Bacteria_Trt_adonis.tsv
#  create mode 100644 Amplicons/Results/Adonis/Bacteria_sType_adonis.tsv
#  create mode 100644 Amplicons/Results/Alpha_rarefaction/Archaea-alpha_rarefaction.qzv
#  create mode 100644 Amplicons/Results/Alpha_rarefaction/Bacteria-alpha_rarefaction.qzv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_KW_Trt.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_KW_sType.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_anova_Trt.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_anova_Trt_pairs.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_anova_Trt_residuals.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_anova_sType.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_anova_sType_pairs.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Archaea_anova_sType_residuals.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_KW_Trt.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_KW_sType.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_anova_Trt.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_anova_Trt_pairs.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_anova_Trt_residuals.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_anova_sType.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_anova_sType_pairs.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/Bacteria_anova_sType_residuals.tsv
#  create mode 100644 Amplicons/Results/Alpha_test/alpha_normality.tsv
#  create mode 100644 Amplicons/Results/AncomBC/Archaea-FL/da-barplot.qzv
#  create mode 100644 Amplicons/Results/AncomBC/Archaea-FL/differentials.qza
#  create mode 100644 Amplicons/Results/AncomBC/Archaea-FL/table.qza
#  create mode 100644 Amplicons/Results/AncomBC/Archaea-FR/da-barplot.qzv
#  create mode 100644 Amplicons/Results/AncomBC/Archaea-FR/differentials.qza
#  create mode 100644 Amplicons/Results/AncomBC/Archaea-FR/table.qza
#  create mode 100644 Amplicons/Results/AncomBC/Bacteria-FL/da-barplot.qzv
#  create mode 100644 Amplicons/Results/AncomBC/Bacteria-FL/differentials.qza
#  create mode 100644 Amplicons/Results/AncomBC/Bacteria-FL/table.qza
#  create mode 100644 Amplicons/Results/AncomBC/Bacteria-FR/da-barplot.qzv
#  create mode 100644 Amplicons/Results/AncomBC/Bacteria-FR/differentials.qza
#  create mode 100644 Amplicons/Results/AncomBC/Bacteria-FR/table.qza
#  create mode 100644 Amplicons/Results/AncomBC/summ.tsv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/FL_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/FL_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/FL_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/FR_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/FR_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/FR_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/RF_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/RF_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/RF_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/RSP_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/RSP_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/RSP_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/Rusitec_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/Rusitec_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/Rusitec_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/bray_curtis_distances_melted.tsv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/evenness_vector.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/faith_pd_vector.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/jaccard_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/jaccard_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/jaccard_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/observed_features_vector.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/rarefied_table.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/shannon_vector.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/unweighted_unifrac_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/unweighted_unifrac_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/unweighted_unifrac_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/weighted_unifrac_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/weighted_unifrac_emperor.qzv
#  create mode 100644 Amplicons/Results/Archaea-Core-metrics/weighted_unifrac_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/FL_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/FL_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/FL_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/FR_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/FR_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/FR_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/RF_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/RF_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/RF_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/RSP_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/RSP_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/RSP_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/Rusitec_bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/Rusitec_bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/Rusitec_bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/bray_curtis_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/bray_curtis_distances_melted.tsv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/bray_curtis_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/bray_curtis_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/evenness_vector.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/faith_pd_vector.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/jaccard_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/jaccard_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/jaccard_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/observed_features_vector.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/rarefied_table.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/shannon_vector.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/unweighted_unifrac_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/unweighted_unifrac_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/unweighted_unifrac_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/weighted_unifrac_distance_matrix.qza
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/weighted_unifrac_emperor.qzv
#  create mode 100644 Amplicons/Results/Bacteria-Core-metrics/weighted_unifrac_pcoa_results.qza
#  create mode 100644 Amplicons/Results/Taxabarplots/Archaea-taxabarplot.qzv
#  create mode 100644 Amplicons/Results/Taxabarplots/Bacteria-taxabarplot.qzv
#  create mode 100644 Amplicons/Results/Taxabarplots/FL_AB-ratios_anova_Trt.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/FL_AB-ratios_anova_Trt_pairs.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/FL_AB-ratios_anova_Trt_residuals.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/FR_AB-ratios_anova_Trt.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/FR_AB-ratios_anova_Trt_pairs.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/FR_AB-ratios_anova_Trt_residuals.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/KW_sType_Archaea.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/KW_sType_Bacteria.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/Trts_Archaea.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/Trts_Bacteria.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Archaea-FL.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Archaea-FR.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Archaea-RF.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Archaea-RSP.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Archaea.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Bacteria-FL.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Bacteria-FR.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Bacteria-RF.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Bacteria-RSP.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-Bacteria.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Archaea-FL.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Archaea-FR.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Archaea-RF.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Archaea-RSP.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Bacteria-FL.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Bacteria-FR.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Bacteria-RF.tsv
#  create mode 100644 Amplicons/Results/Taxabarplots/relative-by-sType-Bacteria-RSP.tsv
#  create mode 100755 Amplicons/barcodes.tsv
#  create mode 100755 Amplicons/metadata.tsv
#  create mode 100644 Git.ipynb
#  create mode 100644 MAGs/.ipynb_checkpoints/Assembly-checkpoint.ipynb
#  create mode 100644 MAGs/.ipynb_checkpoints/MAGs_pool-checkpoint.ipynb
#  create mode 100644 MAGs/Assembly.ipynb
#  create mode 100644 MAGs/MAGs/rstcMAG_005.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_007.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_010.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_014.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_015.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_017.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_018.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_020.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_032.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_034.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_036.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_042.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_043.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_044.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_049.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_054.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_057.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_058.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_059.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_064.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_069.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_070.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_071.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_072.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_080.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_081.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_085.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_091.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_093.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_095.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_098.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_100.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_104.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_110.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_112.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_127.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_130.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_142.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_150.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_155.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_171.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_172.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_173.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_175.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_180.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_181.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_186.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_189.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_193.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_204.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_216.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_217.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_221.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_228.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_229.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_230.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_234.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_237.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_238.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_244.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_245.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_253.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_255.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_268.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_276.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_280.fasta.gz
#  create mode 100644 MAGs/MAGs/rstcMAG_284.fasta.gz
#  create mode 100644 MAGs/MAGs_pool.ipynb
#  create mode 100644 MAGs/MetaPhlan4.ipynb
#  create mode 100644 MAGs/Metawrap_SM.ipynb
#  create mode 100644 MAGs/mOTUlizer.tsv
#  create mode 100644 MAGs/mOTUs.tsv
#  create mode 100644 MAGs/metadata.tsv
#  create mode 100755 Shotgun/Assembly.ipynb
#  create mode 100644 Shotgun/Data/18.Annotated_MAGs.bintable
#  create mode 100755 Shotgun/Data/CAZyDB.07302020.fam-activities.txt
#  create mode 100755 Shotgun/Data/CAZyDB.07302020.fam.subfam.ec.txt
#  create mode 100755 Shotgun/Data/CAZy_activities.tsv
#  create mode 100755 Shotgun/Data/COG-names.tsv
#  create mode 100644 Shotgun/Data/FTables/KO_methane_table.qza
#  create mode 100644 Shotgun/Data/FTables/KO_methane_table.qzv
#  create mode 100644 Shotgun/Data/FTables/KO_methane_table.tsv
#  create mode 100644 Shotgun/Data/FTables/KO_raw_abundance.tsv
#  create mode 100644 Shotgun/Data/FTables/KO_table.qza
#  create mode 100644 Shotgun/Data/FTables/KO_table.qzv
#  create mode 100644 Shotgun/Data/FTables/KO_table.tsv
#  create mode 100644 Shotgun/Data/FTables/KO_table_PWY.qza
#  create mode 100644 Shotgun/Data/FTables/PWY_table.tsv
#  create mode 100755 Shotgun/Data/KEGG-names.tsv
#  create mode 100644 Shotgun/Data/KO-taxonomy.qza
#  create mode 100644 Shotgun/Data/KO-taxonomy.tsv
#  create mode 100644 Shotgun/Data/MAGs_gtdb_taxa.tsv
#  create mode 100644 Shotgun/Data/MAGs_taxonomy.tsv
#  create mode 100644 Shotgun/Data/MTables/.ipynb_checkpoints/bintable_cov-checkpoint.tsv
#  create mode 100644 Shotgun/Data/MTables/bintable.tsv
#  create mode 100644 Shotgun/Data/MTables/bintable_cov.tsv
#  create mode 100644 Shotgun/Data/MTables/bintable_tpm.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00174_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00344_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00345_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00346_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00356_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00357_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00358_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00378_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00422_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00563_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00567_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00608_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/M00935_source.tsv
#  create mode 100644 Shotgun/Data/Methane_modules/Methane_metabolism_KOs.tsv
#  create mode 100644 Shotgun/Data/Tables/All-domains_rel_table.qza
#  create mode 100644 Shotgun/Data/Tables/All-domains_rel_table.tsv
#  create mode 100644 Shotgun/Data/Tables/All-domains_table.qza
#  create mode 100755 Shotgun/Data/Tables/Archaea-Bacteria-domains_rel_table.qza
#  create mode 100755 Shotgun/Data/Tables/Archaea-Bacteria-domains_rel_table.tsv
#  create mode 100755 Shotgun/Data/Tables/Archaea-Bacteria-domains_table.qza
#  create mode 100755 Shotgun/Data/Tables/Archaea-species-rel_table.qza
#  create mode 100755 Shotgun/Data/Tables/Archaea-species-rel_table.tsv
#  create mode 100755 Shotgun/Data/Tables/Archaea-species-table.qza
#  create mode 100755 Shotgun/Data/Tables/Archaea-species-table.qzv
#  create mode 100755 Shotgun/Data/Tables/Archaea-species_rel_table.qza
#  create mode 100755 Shotgun/Data/Tables/Bacteria-species-table.qza
#  create mode 100755 Shotgun/Data/Tables/Bacteria-species-table.qzv
#  create mode 100755 Shotgun/Data/Tables/Bacteria-species_rel_table.qza
#  create mode 100644 Shotgun/Data/Tables/Eukaryota-species-table.qza
#  create mode 100644 Shotgun/Data/Tables/Eukaryota-species-table.qzv
#  create mode 100755 Shotgun/Data/Tables/species-table.qza
#  create mode 100755 Shotgun/Data/Tables/species-table.qzv
#  create mode 100644 Shotgun/Data/gtdbtk.ar53.summary.tsv
#  create mode 100644 Shotgun/Data/gtdbtk.bac120.summary.tsv
#  create mode 100755 Shotgun/Data/taxonomy.qza
#  create mode 100755 Shotgun/Data/taxonomy.tsv
#  create mode 100644 Shotgun/Figures/AncomBC/Ancom-BC.png
#  create mode 100755 Shotgun/Figures/Clades/sgmt-ro_ratios.png
#  create mode 100644 Shotgun/Figures/Clades/sgmt-ro_ratios_anova-pooled.png
#  create mode 100644 Shotgun/Figures/Clades/sgmt-ro_ratios_anova.png
#  create mode 100644 Shotgun/Figures/Maaslin2/KO_Methanogenesis.png
#  create mode 100644 Shotgun/Figures/Maaslin2/KO_Pathways.png
#  create mode 100644 Shotgun/Figures/Maaslin2/Maaslin2_DAF_percentage.png
#  create mode 100755 Shotgun/Functions.ipynb
#  create mode 100644 Shotgun/MAGs.ipynb
#  create mode 100644 Shotgun/Maaslin2.ipynb
#  create mode 100755 Shotgun/Metawrap.ipynb
#  create mode 100755 Shotgun/Results/Alpha_test/Alpha_KW_BS.tsv
#  create mode 100755 Shotgun/Results/Alpha_test/Alpha_KW_BS_Treatment.tsv
#  create mode 100644 Shotgun/Results/Ancom-BC/summ.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_AB_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_AB_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_AB_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_AE_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_AE_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_AE_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_EB_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_EB_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_EB_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_Mbb_clades_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_Mbb_clades_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FL_Mbb_clades_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AB_ratios_anova_BS*Trt+Run.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AB_ratios_anova_BS*Trt+Run_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AB_ratios_anova_BS*Trt+Run_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AB_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AB_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AB_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AE_ratios_anova_BS*Trt+Run.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AE_ratios_anova_BS*Trt+Run_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AE_ratios_anova_BS*Trt+Run_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AE_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AE_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_AE_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_EB_ratios_anova_BS*Trt+Run.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_EB_ratios_anova_BS*Trt+Run_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_EB_ratios_anova_BS*Trt+Run_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_EB_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_EB_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_EB_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_Mbb_clades_ratios_anova_BS*Trt+Run.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_Mbb_clades_ratios_anova_BS*Trt+Run_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_Mbb_clades_ratios_anova_BS*Trt+Run_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_Mbb_clades_ratios_anova_Trt.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_Mbb_clades_ratios_anova_Trt_pairs.tsv
#  create mode 100644 Shotgun/Results/Clades/FR_Mbb_clades_ratios_anova_Trt_residuals.tsv
#  create mode 100644 Shotgun/Results/Clades/Mbb_clades_ratios_normality.tsv
#  create mode 100644 Shotgun/Results/Clades/rats_normality.tsv
#  create mode 100644 Shotgun/Results/FAdonis/KO_BS_adonis.tsv
#  create mode 100644 Shotgun/Results/FAdonis/KO_Trt_adonis.tsv
#  create mode 100644 Shotgun/Results/FAdonis/KO_methane_BS_adonis.tsv
#  create mode 100644 Shotgun/Results/FAdonis/KO_methane_Trt_adonis.tsv
#  create mode 100644 Shotgun/Results/Maaslin2/Maaslin2_DAF_percentage.tsv
#  create mode 100644 Shotgun/Results/Maaslin2/Maaslin2_summ_KO.tsv
#  create mode 100644 Shotgun/Results/Maaslin2/Maaslin2_summ_KO_methane.tsv
#  create mode 100644 Shotgun/Results/Maaslin2/Maaslin2_summ_PWY.tsv
#  create mode 100755 Shotgun/Results/Permanova/BS_Treatment.tsv
#  create mode 100755 Shotgun/Results/Permanova/Pooled_BS.tsv
#  create mode 100755 Shotgun/Taxonomy.ipynb
#  create mode 100644 Shotgun/metadata.tsv

# %%
# !git push -f origin main
# Out:
# Enumerating objects: 518, done.
# Counting objects: 100% (518/518), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (511/511), done.
# Writing objects: 100% (518/518), 98.29 MiB | 6.42 MiB/s, done.
# Total 518 (delta 139), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (139/139), done.
# To github.com:timyerg/Rusitec_2020.git
#  + 09b1c30...6fb4397 main -> main (forced update)
